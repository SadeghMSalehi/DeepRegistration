# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from os import chdir
chdir('../')
from util import (
    load_3d_data,
    create_rotation_matrix,
    create_affine_matrix,
    similarity_transform_volumes,
    vrrotvec2mat,
    vrrotmat2vec,
)

# %%
data_path = './SampleData/nT37template.nii'

# %%
img, img_affine = load_3d_data(data_path)

# %%
plt.imshow(img[:,:,90])

# %%
affine, rotation = create_affine_matrix([0.98,1.02],
                             [-20,20],
                             [-3,3],
                             img.shape)

# %%
img_t, transform = similarity_transform_volumes(
    img,
    affine,
    target_size,
)
# Out:
# /usr/local/lib/python2.7/dist-packages/nilearn/image/resampling.py:518: UserWarning: Casting data from int16 to float32
#   warnings.warn("Casting data from %s to %s" % (data.dtype.name, aux))

# %%
plt.imshow(img_t[:,:,60])

# %%
print(rotation)
# Out:
# [-11.80020692  18.84743554   9.17753699]

# %%
rot = create_rotation_matrix(rotation)

# %%
print(rot)
# Out:
# [[ 0.93426737 -0.22134129  0.27955772]
#  [ 0.15094243  0.95579932  0.25231736]
#  [-0.32304932 -0.19353475  0.92638191]]
